# %% [markdown]
# # Imports and Config

# %% [markdown]
# ## Imports

# %%
# !pip install datasets[vision]
# Out:
# Requirement already satisfied: datasets[vision] in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (9.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (3.8.6)
# Requirement already satisfied: huggingface-hub>=0.18.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (0.19.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (6.0.1)
# Requirement already satisfied: Pillow>=6.2.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]) (9.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (3.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets[vision]) (3.13.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.18.0->datasets[vision]) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets[vision]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets[vision]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets[vision]) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets[vision]) (1.16.0)

# %%
import numpy as np
import pandas as pd
import os
import tqdm
import random
import re
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import textwrap

from datasets import load_dataset

import torch
from torchvision import transforms
import torch
import torchtext

# %% [markdown]
# ## Data Loading

# %% [markdown]
# ### WikiArt Artist Data

# %%
# load in wikiart artist information
artists_info = pd.read_csv('artists.csv')

# %%
artist_names = set(list(artists_info['Name'].str.strip().str.lower()))

# %%
movements = set(artists_info['ArtMovements'].str.split(',').explode().str.strip().str.lower().value_counts()[:15].index.tolist())

# %%
movements
# Out:
# {'abstract art',
#  'abstract expressionism',
#  'academic art',
#  'art nouveau',
#  'baroque',
#  'conceptual art',
#  'contemporary',
#  'expressionism',
#  'impressionism',
#  'minimalism',
#  'pop art',
#  'post-impressionism',
#  'realism',
#  'romanticism',
#  'surrealism'}

# %%
genres = set(artists_info['Genres'].str.split(',').explode().str.strip().str.lower().value_counts()[:15].index.tolist())

# %%
genres
# Out:
# {'abstract',
#  'animal painting',
#  'cityscape',
#  'figurative',
#  'genre painting',
#  'history painting',
#  'illustration',
#  'installation',
#  'landscape',
#  'marina',
#  'photo',
#  'portrait',
#  'religious painting',
#  'sculpture',
#  'still life'}

# %% [markdown]
# ### DiffusionDB Data

# %%
# Load diffusionDB - random 10,000 images
gen_imgs = load_dataset('poloclub/diffusiondb', '2m_first_1k')
# load only img and prompt
gen_imgs = gen_imgs['train'].select_columns(['prompt', 'image'])
# Out:
# Downloading builder script:   0%|          | 0.00/15.2k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/25.0k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/581M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/195M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# get average image resolution
avg_res_y = gen_imgs['image']
avg_res_x = gen_imgs['image'].size().mean()
print(f'Average image resolution: {avg_res_x}x{avg_res_y}')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-6b6798adc3a4> in <cell line: 2>()
#       1 # get average image resolution
# ----> 2 avg_res_y = gen_imgs['image'].size().mean()
#       3 avg_res_x = gen_imgs['image'].map(lambda x: x.shape[0]).mean()
#       4 print(f'Average image resolution: {avg_res_x}x{avg_res_y}')
#
# AttributeError: 'list' object has no attribute 'size'

# %%
np.array([i.size for i in gen_imgs['image']]).mean(axis=0)
# Out:
# array([583.808, 603.264])

# %% [markdown]
# ## Data Sampling
# Defines a helper function to take a random slice of data and plot it

# %%
def sample_data(indices, data):
  # helper function to show prompt and image
    num_rows = len(indices)

    # Create a new figure with subplots
    fig, axes = plt.subplots(num_rows, 1, figsize=(5, 5 * num_rows))

    # Iterate over the indices and plot images with wrapped titles
    for i, index in enumerate(indices):
        prompt = data[int(index)]['prompt']
        img = data[int(index)]['image']

        # Plot the image
        axes[i].imshow(img)
        axes[i].axis('off')

        # Wrap the prompt text to fit the width of the plot
        wrapped_text = textwrap.fill(prompt, width=60)  # Adjust the width as needed

        # Set the wrapped title of the subplot
        axes[i].set_title(wrapped_text, fontsize=11, ha='center')
    # add space to accomodate titles
    plt.subplots_adjust(hspace=0.3)

    # Show the plot
    plt.show()

def get_random_samples(sample_size, data):
  # function to get random promts and images
  random_indices = np.random.randint(0, len(data), sample_size)
  sample_data(random_indices, data)

  return data.select([int(i) for i in random_indices])

random_samples = get_random_samples(4, gen_imgs)

# %% [markdown]
# ## Data Filtering

# %%
# filter the data based on prompts with positive search terms and negative negation terms
filtered_rowsets = []
negation_terms = ['3d', 'sci-fi', 'digital', 'photo', 'photograph', 'photography', 'render', '4k', 'deviantart', 'cinematic', '4 k', 'cyberpunk']
art_terms = ['on canvas', 'oil painting', 'watercolours', 'watercolors', 'watercolor','acrylic', 'brush strokes', 'painting']
for filter_terms in [artist_names, genres, art_terms]:
  # filter positively on filter terms
  filtered = gen_imgs.filter(lambda x: any(s in x['prompt'].lower() for s in filter_terms))
  # filter negatively on negation terms
  filtered = filtered.filter(lambda x: not any(s in x['prompt'].lower() for s in negation_terms))
  filtered_rowsets.append(filtered)
  print(len(filtered))
# Out:
# 12644
# 12522
# 10599

# %% [markdown]
# ### Filtered data based on artist names
# Here data is filtered based on it containing references to any artists contained in the wikiArt dataset

# %%
random_artists = get_random_samples(10, filtered_rowsets[0])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Filtered data based on art genres
# Data here is filtered based on the prompt containing keywords consisting of the top 10 most frequently used genre of art an artist belongs to according to WikiArt

# %%
random_genres = get_random_samples(10, filtered_rowsets[1])
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ### Filtered data based on art-words
# Here data is filtered based on art keywords like oil painting, canvas, etc

# %%
random_art_terms = get_random_samples(10, filtered_rowsets[2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6efcee382949> in <cell line: 1>()
# ----> 1 random_art_terms = get_random_samples(10, filtered_rowsets[2])
#
# NameError: name 'get_random_samples' is not defined
