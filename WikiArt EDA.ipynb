# %% [markdown]
# # Imports and Config

# %%
#!pip install scrapy
#!pip install datasets[vision]

#import scrapy
#from scrapy.crawler import CrawlerProcess
from bs4 import BeautifulSoup
import pdb
import pandas as pd
import numpy as np
from datasets import load_dataset
import os 
import random
from tqdm.notebook import tqdm
import json
import zipfile
import io

# %% [markdown]
# # Scraper - Get artist info from WikiArt Website

# %%
class ArtistItem(scrapy.Item):
    Id = scrapy.Field()
    URL = scrapy.Field()
    Name = scrapy.Field()
    OriginalName = scrapy.Field()
    BirthDate = scrapy.Field()
    BirthPlace = scrapy.Field()
    DeathDate = scrapy.Field()
    DeathPlace = scrapy.Field()
    ActiveYears = scrapy.Field()
    Nationality = scrapy.Field()
    ArtMovements = scrapy.Field()
    PaintingSchool = scrapy.Field()
    Genres = scrapy.Field()
    Fields = scrapy.Field()
    InfluencedOn = scrapy.Field()
    InfluencedBy = scrapy.Field()
    Teachers = scrapy.Field()
    Pupils = scrapy.Field()
    ArtInstitutions = scrapy.Field()
    FriendsAndCoworkers = scrapy.Field()
    Description = scrapy.Field()
    WikiDescription = scrapy.Field()
    WikipediaLink = scrapy.Field()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rmohe01/MIE1517/MIE1517_Project/WikiArt EDA.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rmohe01/MIE1517/MIE1517_Project/WikiArt%20EDA.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> class ArtistItem(scrapy.Item):
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rmohe01/MIE1517/MIE1517_Project/WikiArt%20EDA.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     Id = scrapy.Field()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/home/rmohe01/MIE1517/MIE1517_Project/WikiArt%20EDA.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     URL = scrapy.Field()
#
# NameError: name 'scrapy' is not defined

# %%
class WikiArtArtistSpider(scrapy.Spider):
    name = "wikiart_artist"
    allowed_domains = ["wikiart.org"]
    start_urls = ["https://www.wikiart.org/en/artists-by-nation"]
    id = 0

    custom_settings = {
        'FEEDS': {
            'artists.csv': {
                'format': 'csv',
                'overwrite': True
            }
        }
    }


    def parse(self, response):
        for nation in response.xpath('//main/ul/li/a/@href').getall():
            yield response.follow(nation + "/text-list", callback=self.parse_nation)

    def parse_nation(self, response):
        for artist in response.xpath('//main/div/ul/li/a/@href').getall():
            yield response.follow(artist, callback=self.parse_artist)

    def parse_artist(self, response):
        name_raw = response.xpath('//main/div/article/h3/text()')
        name = name_raw.get().replace("  ", '').replace('\n', '') if name_raw else name_raw
        original_name_raw = response.xpath('//main/div/article/h4/text()').get()
        original_name = original_name_raw.replace("  ", '').replace('\n', '') if original_name_raw else original_name_raw

        birth_date = response.xpath('//main/div/article/ul/li/span[@itemprop="birthDate"]/text()').get()
        birth_place = response.xpath('//main/div/article/ul/li/span[@itemprop="birthPlace"]/text()').get()

        death_date = response.xpath('//main/div/article/ul/li/span[@itemprop="deathDate"]/text()').get()
        death_place = response.xpath('//main/div/article/ul/li/span[@itemprop="deathPlace"]/text()').get()

        active_years_raw = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Active Years:")]]]').get()
        active_years = active_years_raw.replace("<li>\n            <s>Active Years:</s>\n            ", '')\
            .replace("\n        </li>", '') if active_years_raw else active_years_raw

        nationality = response.xpath('//span[@itemprop="nationality"]/text()').get()

        art_movements = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Art Movement:")]]]/span/a/text()').getall()
        painting_school = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Painting School:")]]]/span/a/text()').getall()

        genres = response.xpath('//span[@itemprop="genre"]/text()').getall()
        fields = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Field:")]]]/span/a/text()').getall()

        influenced_by = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Influenced by:")]]]/a/text()').getall()
        influenced_on = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Influenced on:")]]]/a/text()').getall()

        teachers = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Teachers:")]]]/a/text()').getall()
        pupils = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Pupils:")]]]/a/text()').getall()

        art_institutions = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Art institution:")]]]/a/text()').getall()

        friends_and_coworkers = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Friends and Co-workers:")]]]/a/text()').getall()

        wikipedia_link = response.xpath('//main/div/article/ul/li[.//s[text()[contains(.,"Wikipedia:")]]]/a/@href').get()

        description_raw = response.xpath('//p[@itemprop="description"]').get()
        description = BeautifulSoup(description_raw, features="lxml").get_text() if description_raw else description_raw

        wiki_description_raw = response.xpath('//div[@id="info-tab-wikipediaArticle"]/p').get()
        wiki_description = BeautifulSoup(wiki_description_raw, features="lxml").get_text() if wiki_description_raw else wiki_description_raw

        yield ArtistItem({
            "Id": self.id,
            "URL": response.url,
            "Name": name,
            "OriginalName": original_name,
            "BirthDate": birth_date,
            "BirthPlace": birth_place,
            "DeathDate": death_date,
            "DeathPlace": death_place,
            "ActiveYears": active_years,
            "Nationality": nationality,
            "ArtMovements": art_movements,
            "PaintingSchool": painting_school,
            "Genres": genres,
            "Fields": fields,
            "InfluencedOn": influenced_on,
            "InfluencedBy": influenced_by,
            "Teachers": teachers,
            "Pupils": pupils,
            "ArtInstitutions": art_institutions,
            "FriendsAndCoworkers": friends_and_coworkers,
            "WikipediaLink": wikipedia_link,
            "Description": description,
            "WikiDescription": wiki_description,
        })

        self.id += 1

# %%
process = CrawlerProcess()
process.crawl(WikiArtArtistSpider)
process.start()
# Out:
# Streaming output truncated to the last 5000 lines.
#  'InfluencedOn': [],
#  'Name': 'Bada Shanren ',
#  'Nationality': 'Chinese',
#  'OriginalName': '朱耷',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/bada-shanren',
#  'WikiDescription': 'Bada Shanren (born Zhu Da ca. 1626—1705) was a Han '
#                     'Chinese painter of ink wash painting and a calligrapher. '
#                     'He was of royal descent, being a direct offspring of the '
#                     'Ming dynasty prince Zhu Quan who had a feudal '
#                     "establishment in Nanchang. His master lineage's accession "
#                     'was revoked following the last Ning Lineage King Zhu '
#                     "Chenhao's rebellion in 1521, but the rest of the lineage "
#                     'was allowed to retain status in Jiangxi. Art historians '
#                     'have named him as a brilliant painter of the period.\r'
#                     ' Bada Shanren, a purported child prodigy born to a '
#                     'handicapped father, began painting and writing poetry in '
#                     'his early childhood. About the year 1644, when the Ming '
#                     'emperor committed suicide and the Manchu army from the '
#                     'north attacked Beijing, the young Han Chinese man sought '
#                     'refuge in a vihara. Because he was a Ming prince, the '
#                     'dynastic upheaval created a great amount of uncertainty '
#                     'for his position in society. As years passed and the '
#                     'Manchurian court became more firmly established, there '
#                     'was less and less insecurity among the Qing regime about '
#                     'remaining Ming loyalties and possible future rebellions. '
#                     'Due to these more stable circumstances, after 40 years, '
#                     'Bada Shanren deemed it acceptable to leave the monastery '
#                     'and to re-enter day-to-day life among society. In the '
#                     'aftermath of a nervous breakdown that could have been '
#                     'staged to avoid retribution for his family background, '
#                     'Zhu Da abandoned his monastic life and developed a career '
#                     'as a professional painter, adopting a series of '
#                     'descriptive pseudonyms, most notably Bada Shanren by '
#                     'which he is most often known today. He is said to have '
#                     'screamed and made weird sounds while painting. The '
#                     'stylized vertical writing of his pseudonym Bada Shanren '
#                     '(八大山人) looks like the characters for laugh (笑) and cry '
#                     '(哭), thus by signing his paintings he implied his '
#                     'confusion and feelings of grief for the fate of his '
#                     'country and home.\r'
#                     ' His paintings feature sharp brush strokes which are '
#                     'attributed to the sideways manner by which he held his '
#                     'brush. In the 1930s, Chinese painter Zhang Daqian '
#                     "produced several forgeries of Bada Shanren's works but "
#                     'they are easily spotted by the trained eye, because the '
#                     'modern copies were softer and rounder. Yale University '
#                     'scholar Fred Fangyu Wang was a major collector of Bada '
#                     'Shanren paintings from the 1960s until his death in 1997.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Bada_Shanren'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/chen-hongshou> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:19 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/chen-hongshou> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/victo-ngai>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Neo-Surrealism', 'Fantasy Art'],
#  'BirthDate': '1988',
#  'BirthPlace': 'China',
#  'DeathDate': None,
#  'DeathPlace': None,
#  'Description': 'Victo Ngai (倪傳婧), was born in South China in 1988 in '
#                 'Guangdong Province. Ngai grew up in British colonized Hong '
#                 'Kong before enrolling in Rhode Island School of Design (RISD) '
#                 'in 2006. She shortened her name to "Victo" from "Victoria" - '
#                 'a name she considers leftover from the British colonization '
#                 'of Hong Kong. Until the age of 6, Ngai would be plagued by '
#                 'fevers that induced near-fatal seizures. With nowhere else to '
#                 "turn, Ngai's mother turned to herbal treatments to cure her. "
#                 "It was at this point that Ngai's mother recognized her "
#                 "daughter's artistic talent, and so, she took Ngai to a "
#                 'private art teacher in Shenzen. Ngai would build incredibly '
#                 'on her skills and in 2006 she applied, and was accepted, into '
#                 'RISD, the only school she applied to. At RISD, Ngai was '
#                 'heavily inspired by her professor, editorial illustrator, '
#                 "Chris Buzelli. Initially, Ngai struggled in Buzelli's "
#                 'editorial course, but when Buzelli had encouraged her to '
#                 'pursue the incredible line-work displayed in her sketchbooks, '
#                 'Ngai had an artistic breakthrough. Her work and signature '
#                 'neo-surrealistic style would soon become instantly '
#                 "recognizable to anyone who saw it. In Ngai's junior year of "
#                 'college, she landed her first client-PLANSPONSOR Magazine, '
#                 "art directed by SooJin Buzelli. Ngai's second client would be "
#                 'The New York Times. Ngai would soon land several major '
#                 'clients including The New Yorker, NBC, Dreamworks, Penguin '
#                 'Random House, Simon & Schuster, Apple, and American Express. '
#                 'Currently, Ngai works freelance out of Los Angeles. She '
#                 'taught at the School of Visual Arts (SVA) in New York City, '
#                 'and recently won gold for advertising at the Society of '
#                 "Illustrator's 61.",
#  'Fields': ['illustration'],
#  'FriendsAndCoworkers': [],
#  'Genres': ['illustration'],
#  'Id': 3488,
#  'InfluencedBy': ['Utagawa Kuniyoshi', 'Hiroshige', 'Norman Rockwell'],
#  'InfluencedOn': [],
#  'Name': 'Victo Ngai ',
#  'Nationality': 'Chinese',
#  'OriginalName': '倪傳婧',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/victo-ngai',
#  'WikiDescription': 'Victo Ngai (born 1988) is an American illustrator raised '
#                     'in Hong Kong. Her work has been described as being highly '
#                     'detailed and precise, referencing comic book drawings, '
#                     "classic children's book illustrations, the work of "
#                     'Japanese painters, and more. Illustrations created by the '
#                     'artist are often considered to contain compelling imagery '
#                     'and unique styling.  Ngai (pronounced nye), was given the '
#                     'name of Victoria, which she later shortened to Victo. '
#                     'Born in  Guangdong Province  and raised in the former '
#                     'British colony of Hong Kong as the only child of '
#                     "middle-class parents, Ngais' father worked in finance and "
#                     'her mother worked in a variety of jobs, including '
#                     'professor of Chinese literature, newspaper editor and the '
#                     'manager of an investment company. Often bedridden with '
#                     'high fevers until the age of six she took to drawing as a '
#                     'way to keep herself entertained. Her mother sought out '
#                     'traditional herbal treatments, which not only ended her '
#                     'fevers but also inspired her mother’s next career as a '
#                     'doctor of Chinese medicine   Her great uncle was a '
#                     'surgeon with a passion for meticulous Chinese ink '
#                     'painting and drawing with him was one of her first art '
#                     'encounters. Ngai also went to many museum exhibitions '
#                     "with her mother as a child.  The artist's family  moved "
#                     'from place to place often when she was young, which did '
#                     'not allow for lasting friendships and as a result her '
#                     'childhood was a largely solitary one. Ngai would later '
#                     'credit the instability in her early life with the birth '
#                     "of her artistic identity.  Ngai's mother first noticed "
#                     'her artistic talented and feared that "rigidly technical '
#                     'Chinese art taught in school was stifling it." For two '
#                     'years during summer vacation, Ngai was taken to a private '
#                     'art teacher in Shenzhen on mainland China, which although '
#                     'geographically close, was like "visiting another country" '
#                     'because of the customs immigration process, according to '
#                     'the artist. It was there that Ngai’s creative confidence '
#                     'began to flourish.  When Ngai started thinking about an '
#                     'education in illustration, it was a difficult decision, '
#                     'because the artist and her family believed there was a '
#                     'prejudice in Asia against art and design. Her father '
#                     'hoped she would go into finance as a career.  A friend '
#                     'who studied art at Yale, recommended the Rhode Island '
#                     'School of Design and that was the only school she applied '
#                     'to.Ngai was accepted at the Rhode Island School of Design '
#                     'in 2006 where she was mentored by the award-winning '
#                     'illustrator, Chris Buzelli, who importantly taught the '
#                     'young artist that an individual style is something you '
#                     'have to search for within, and not search for outside.  '
#                     'The artist drew early influences from the works of '
#                     'Utagawa Kuniyoshi, Hiroshige and her college instructor, '
#                     'Chris Buzelli She also gained inspiration from Norman '
#                     'Rockwell, Windsor McCay, Mary Blair and the fashion '
#                     'designer Alexander McQueen.  When asked why she became an '
#                     'illustrator instead of a fine artist, Ngai replied, "One '
#                     'of my RISD professors told me this back in freshmen year, '
#                     "'Fine artists like to create problems for themselves "
#                     "while illustrators like to solve problems given to them'. "
#                     'I love drawing and I love problem solving, hence '
#                     'illustration."',
#  'WikipediaLink': 'https://en.wikipedia.org/wiki/Victo_Ngai'}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/victo-ngai>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Neo-Surrealism', 'Fantasy Art'],
#  'BirthDate': '1988',
#  'BirthPlace': 'China',
#  'DeathDate': None,
#  'DeathPlace': None,
#  'Description': 'Victo Ngai (倪傳婧), was born in South China in 1988 in '
#                 'Guangdong Province. Ngai grew up in British colonized Hong '
#                 'Kong before enrolling in Rhode Island School of Design (RISD) '
#                 'in 2006. She shortened her name to "Victo" from "Victoria" - '
#                 'a name she considers leftover from the British colonization '
#                 'of Hong Kong. Until the age of 6, Ngai would be plagued by '
#                 'fevers that induced near-fatal seizures. With nowhere else to '
#                 "turn, Ngai's mother turned to herbal treatments to cure her. "
#                 "It was at this point that Ngai's mother recognized her "
#                 "daughter's artistic talent, and so, she took Ngai to a "
#                 'private art teacher in Shenzen. Ngai would build incredibly '
#                 'on her skills and in 2006 she applied, and was accepted, into '
#                 'RISD, the only school she applied to. At RISD, Ngai was '
#                 'heavily inspired by her professor, editorial illustrator, '
#                 "Chris Buzelli. Initially, Ngai struggled in Buzelli's "
#                 'editorial course, but when Buzelli had encouraged her to '
#                 'pursue the incredible line-work displayed in her sketchbooks, '
#                 'Ngai had an artistic breakthrough. Her work and signature '
#                 'neo-surrealistic style would soon become instantly '
#                 "recognizable to anyone who saw it. In Ngai's junior year of "
#                 'college, she landed her first client-PLANSPONSOR Magazine, '
#                 "art directed by SooJin Buzelli. Ngai's second client would be "
#                 'The New York Times. Ngai would soon land several major '
#                 'clients including The New Yorker, NBC, Dreamworks, Penguin '
#                 'Random House, Simon & Schuster, Apple, and American Express. '
#                 'Currently, Ngai works freelance out of Los Angeles. She '
#                 'taught at the School of Visual Arts (SVA) in New York City, '
#                 'and recently won gold for advertising at the Society of '
#                 "Illustrator's 61.",
#  'Fields': ['illustration'],
#  'FriendsAndCoworkers': [],
#  'Genres': ['illustration'],
#  'Id': 3488,
#  'InfluencedBy': ['Utagawa Kuniyoshi', 'Hiroshige', 'Norman Rockwell'],
#  'InfluencedOn': [],
#  'Name': 'Victo Ngai ',
#  'Nationality': 'Chinese',
#  'OriginalName': '倪傳婧',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/victo-ngai',
#  'WikiDescription': 'Victo Ngai (born 1988) is an American illustrator raised '
#                     'in Hong Kong. Her work has been described as being highly '
#                     'detailed and precise, referencing comic book drawings, '
#                     "classic children's book illustrations, the work of "
#                     'Japanese painters, and more. Illustrations created by the '
#                     'artist are often considered to contain compelling imagery '
#                     'and unique styling.  Ngai (pronounced nye), was given the '
#                     'name of Victoria, which she later shortened to Victo. '
#                     'Born in  Guangdong Province  and raised in the former '
#                     'British colony of Hong Kong as the only child of '
#                     "middle-class parents, Ngais' father worked in finance and "
#                     'her mother worked in a variety of jobs, including '
#                     'professor of Chinese literature, newspaper editor and the '
#                     'manager of an investment company. Often bedridden with '
#                     'high fevers until the age of six she took to drawing as a '
#                     'way to keep herself entertained. Her mother sought out '
#                     'traditional herbal treatments, which not only ended her '
#                     'fevers but also inspired her mother’s next career as a '
#                     'doctor of Chinese medicine   Her great uncle was a '
#                     'surgeon with a passion for meticulous Chinese ink '
#                     'painting and drawing with him was one of her first art '
#                     'encounters. Ngai also went to many museum exhibitions '
#                     "with her mother as a child.  The artist's family  moved "
#                     'from place to place often when she was young, which did '
#                     'not allow for lasting friendships and as a result her '
#                     'childhood was a largely solitary one. Ngai would later '
#                     'credit the instability in her early life with the birth '
#                     "of her artistic identity.  Ngai's mother first noticed "
#                     'her artistic talented and feared that "rigidly technical '
#                     'Chinese art taught in school was stifling it." For two '
#                     'years during summer vacation, Ngai was taken to a private '
#                     'art teacher in Shenzhen on mainland China, which although '
#                     'geographically close, was like "visiting another country" '
#                     'because of the customs immigration process, according to '
#                     'the artist. It was there that Ngai’s creative confidence '
#                     'began to flourish.  When Ngai started thinking about an '
#                     'education in illustration, it was a difficult decision, '
#                     'because the artist and her family believed there was a '
#                     'prejudice in Asia against art and design. Her father '
#                     'hoped she would go into finance as a career.  A friend '
#                     'who studied art at Yale, recommended the Rhode Island '
#                     'School of Design and that was the only school she applied '
#                     'to.Ngai was accepted at the Rhode Island School of Design '
#                     'in 2006 where she was mentored by the award-winning '
#                     'illustrator, Chris Buzelli, who importantly taught the '
#                     'young artist that an individual style is something you '
#                     'have to search for within, and not search for outside.  '
#                     'The artist drew early influences from the works of '
#                     'Utagawa Kuniyoshi, Hiroshige and her college instructor, '
#                     'Chris Buzelli She also gained inspiration from Norman '
#                     'Rockwell, Windsor McCay, Mary Blair and the fashion '
#                     'designer Alexander McQueen.  When asked why she became an '
#                     'illustrator instead of a fine artist, Ngai replied, "One '
#                     'of my RISD professors told me this back in freshmen year, '
#                     "'Fine artists like to create problems for themselves "
#                     "while illustrators like to solve problems given to them'. "
#                     'I love drawing and I love problem solving, hence '
#                     'illustration."',
#  'WikipediaLink': 'https://en.wikipedia.org/wiki/Victo_Ngai'}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/chen-hongshou>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1598',
#  'BirthPlace': 'Zhuji, ZheJiang, China',
#  'DeathDate': '1652',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3489,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Chen Hongshou ',
#  'Nationality': 'Chinese',
#  'OriginalName': '陳洪綬',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/chen-hongshou',
#  'WikiDescription': "Chen Hongshou (1598–1652), formerly romanized as Ch'en "
#                     'Hung-shou, was a Chinese painter of the late Ming '
#                     'dynasty.\r'
#                     ' Chen was born in Zhuji, Zhejiang province in 1598, '
#                     'during the Ming dynasty. His courtesy name was Zhanghou '
#                     '(章侯), and his pseudonyms were Laolian (老莲), Fuchi (弗迟), '
#                     'Yunmenseng (云门僧), Huichi (悔迟), Chiheshang (迟和尚) and '
#                     'Huiseng (悔僧). He once trained under Lan Ying, and was '
#                     'skilled in painting peculiar human figures, landscapes, '
#                     'flower-and-bird. He utilized plump, profound brushwork '
#                     'and precise color, creating a unique style. He always '
#                     'painted illustrations and made tapestry portraits. His '
#                     'two masterpieces," Shui Hu Ye Zi" (水浒叶子) and "Bo Gu Ye '
#                     'Zi", were the rare examples among the Ming and the Qing '
#                     'dynasties. He was very famous at that time, called "Chen '
#                     'in South and Cui in North", together with Cui Zizhong. He '
#                     'also was skilled in calligraphy,poetry and prose.\r'
#                     ' His works are kept in museums and galleries all over the '
#                     'world including these in the United States:',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Chen_Hongshou'}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/chen-hongshou>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1598',
#  'BirthPlace': 'Zhuji, ZheJiang, China',
#  'DeathDate': '1652',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3489,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Chen Hongshou ',
#  'Nationality': 'Chinese',
#  'OriginalName': '陳洪綬',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/chen-hongshou',
#  'WikiDescription': "Chen Hongshou (1598–1652), formerly romanized as Ch'en "
#                     'Hung-shou, was a Chinese painter of the late Ming '
#                     'dynasty.\r'
#                     ' Chen was born in Zhuji, Zhejiang province in 1598, '
#                     'during the Ming dynasty. His courtesy name was Zhanghou '
#                     '(章侯), and his pseudonyms were Laolian (老莲), Fuchi (弗迟), '
#                     'Yunmenseng (云门僧), Huichi (悔迟), Chiheshang (迟和尚) and '
#                     'Huiseng (悔僧). He once trained under Lan Ying, and was '
#                     'skilled in painting peculiar human figures, landscapes, '
#                     'flower-and-bird. He utilized plump, profound brushwork '
#                     'and precise color, creating a unique style. He always '
#                     'painted illustrations and made tapestry portraits. His '
#                     'two masterpieces," Shui Hu Ye Zi" (水浒叶子) and "Bo Gu Ye '
#                     'Zi", were the rare examples among the Ming and the Qing '
#                     'dynasties. He was very famous at that time, called "Chen '
#                     'in South and Cui in North", together with Cui Zizhong. He '
#                     'also was skilled in calligraphy,poetry and prose.\r'
#                     ' His works are kept in museums and galleries all over the '
#                     'world including these in the United States:',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Chen_Hongshou'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/lan-ying> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/lan-ying> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/ding-yanyong> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/ding-yanyong> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/lan-ying>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': 'c.1585',
#  'BirthPlace': 'Hangzhou, Zhejiang, China',
#  'DeathDate': 'c.1664',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3490,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Lan Ying ',
#  'Nationality': 'Chinese',
#  'OriginalName': '藍瑛',
#  'PaintingSchool': ['Zhe School'],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/lan-ying',
#  'WikiDescription': 'Lan Ying (simplified Chinese: 蓝瑛; traditional Chinese: '
#                     '藍瑛; pinyin: Lán Yīng; ca. 1585–1664) was a Chinese '
#                     'painter of landscapes, human figures, flowers and birds '
#                     'who was active during the Ming Dynasty (1368–1644).\r'
#                     ' Lan was born in Hangzhou in the Zhejiang province. His '
#                     "style name was 'Tianshu' (田叔), and his pseudonyms were "
#                     "'Diesou' (蜨叟), 'Shi Toutuo' (石頭陀), and Dongguo laoren'. "
#                     "Lan's painting followed the style of Huang Gongwang and "
#                     'Wu Zhen. Lan was trained at the Painting Academy of the '
#                     "South Song Dynasty. Lan's son Lan Yu and grandson Lan "
#                     'Shen also grew up to be painters.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Lan_Ying'}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/lan-ying>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': 'c.1585',
#  'BirthPlace': 'Hangzhou, Zhejiang, China',
#  'DeathDate': 'c.1664',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3490,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Lan Ying ',
#  'Nationality': 'Chinese',
#  'OriginalName': '藍瑛',
#  'PaintingSchool': ['Zhe School'],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/lan-ying',
#  'WikiDescription': 'Lan Ying (simplified Chinese: 蓝瑛; traditional Chinese: '
#                     '藍瑛; pinyin: Lán Yīng; ca. 1585–1664) was a Chinese '
#                     'painter of landscapes, human figures, flowers and birds '
#                     'who was active during the Ming Dynasty (1368–1644).\r'
#                     ' Lan was born in Hangzhou in the Zhejiang province. His '
#                     "style name was 'Tianshu' (田叔), and his pseudonyms were "
#                     "'Diesou' (蜨叟), 'Shi Toutuo' (石頭陀), and Dongguo laoren'. "
#                     "Lan's painting followed the style of Huang Gongwang and "
#                     'Wu Zhen. Lan was trained at the Painting Academy of the '
#                     "South Song Dynasty. Lan's son Lan Yu and grandson Lan "
#                     'Shen also grew up to be painters.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Lan_Ying'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/qiu-ying> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/qiu-ying> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/ding-yanyong>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Republic of China (1912–1949)'],
#  'BirthDate': '1902',
#  'BirthPlace': 'China',
#  'DeathDate': '1978',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3491,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Ding Yanyong ',
#  'Nationality': 'Chinese',
#  'OriginalName': None,
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/ding-yanyong',
#  'WikiDescription': None,
#  'WikipediaLink': None}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/ding-yanyong>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Republic of China (1912–1949)'],
#  'BirthDate': '1902',
#  'BirthPlace': 'China',
#  'DeathDate': '1978',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3491,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Ding Yanyong ',
#  'Nationality': 'Chinese',
#  'OriginalName': None,
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/ding-yanyong',
#  'WikiDescription': None,
#  'WikipediaLink': None}
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/qiu-ying>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1494',
#  'BirthPlace': 'Taicang, Jiangsu, China',
#  'DeathDate': '1552',
#  'DeathPlace': None,
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3492,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Qiu Ying ',
#  'Nationality': 'Chinese',
#  'OriginalName': "Qiu Ying (仇英; Qiú Yīng; Ch'iu Ying); Shifu (实父); Shizhou "
#                  '(十洲)',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/qiu-ying',
#  'WikiDescription': 'Qiu Ying (Chinese: 仇英; pinyin: Qiú Yīng; Wade–Giles: '
#                     "Ch'iu Ying; 1494? – 1552) was a Chinese painter who "
#                     'specialized in the gongbi brush technique.\r'
#                     " Qiu Ying's courtesy name was Shifu (实父), and his "
#                     'pseudonym was Shizhou (十洲). He was born to a peasant '
#                     'family in Taicang (太仓—now Jiangsu Province) and studied '
#                     "painting under Zhou Chen in Suzhou. Though Suzhou's Wu "
#                     'School encouraged painting in ink washes, Qiu Ying also '
#                     'painted in the green-and-blue style. He painted with the '
#                     'support of wealthy patrons, creating images of flowers, '
#                     'gardens, religious subjects, and landscapes in the '
#                     'fashions of the Ming dynasty. He incorporated different '
#                     'techniques into his paintings, and acquired a few wealthy '
#                     'patrons. His talent and versatility allowed him to become '
#                     'regarded as one of the Four Masters of the Ming dynasty.\r'
#                     ' Three of his best patrons were art collectors. One was '
#                     'Chen Guan from Suzhou. The other two were both younger '
#                     'than Qiu: Zhou Fenglai (1523–1555), from nearby Kunshan, '
#                     'and the well-known wealthy collector Xiang Yuanbian, '
#                     'whose home was in Jiaxing in Zhejiang Province.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Qiu_Ying'}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/qiu-ying>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1494',
#  'BirthPlace': 'Taicang, Jiangsu, China',
#  'DeathDate': '1552',
#  'DeathPlace': None,
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3492,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Qiu Ying ',
#  'Nationality': 'Chinese',
#  'OriginalName': "Qiu Ying (仇英; Qiú Yīng; Ch'iu Ying); Shifu (实父); Shizhou "
#                  '(十洲)',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/qiu-ying',
#  'WikiDescription': 'Qiu Ying (Chinese: 仇英; pinyin: Qiú Yīng; Wade–Giles: '
#                     "Ch'iu Ying; 1494? – 1552) was a Chinese painter who "
#                     'specialized in the gongbi brush technique.\r'
#                     " Qiu Ying's courtesy name was Shifu (实父), and his "
#                     'pseudonym was Shizhou (十洲). He was born to a peasant '
#                     'family in Taicang (太仓—now Jiangsu Province) and studied '
#                     "painting under Zhou Chen in Suzhou. Though Suzhou's Wu "
#                     'School encouraged painting in ink washes, Qiu Ying also '
#                     'painted in the green-and-blue style. He painted with the '
#                     'support of wealthy patrons, creating images of flowers, '
#                     'gardens, religious subjects, and landscapes in the '
#                     'fashions of the Ming dynasty. He incorporated different '
#                     'techniques into his paintings, and acquired a few wealthy '
#                     'patrons. His talent and versatility allowed him to become '
#                     'regarded as one of the Four Masters of the Ming dynasty.\r'
#                     ' Three of his best patrons were art collectors. One was '
#                     'Chen Guan from Suzhou. The other two were both younger '
#                     'than Qiu: Zhou Fenglai (1523–1555), from nearby Kunshan, '
#                     'and the well-known wealthy collector Xiang Yuanbian, '
#                     'whose home was in Jiaxing in Zhejiang Province.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Qiu_Ying'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/tang-yin> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/tang-yin> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/fernando-botero> (referer: https://www.wikiart.org/en/artists-by-nation/colombian/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/fernando-botero> (referer: https://www.wikiart.org/en/artists-by-nation/colombian/text-list)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/tang-yin>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1470',
#  'BirthPlace': 'Suzhou?, China',
#  'DeathDate': '1524',
#  'DeathPlace': None,
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3493,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Tang Yin ',
#  'Nationality': 'Chinese',
#  'OriginalName': 'Tang Yin (唐寅; Táng Yín; Tong Yan; Tang Bohu - 唐伯虎)',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/tang-yin',
#  'WikiDescription': 'Tang Yin (Chinese: 唐寅; pinyin: Táng Yín; Cantonese Yale: '
#                     'Tong Yan; 1470–1524), courtesy name Tang Bohu (唐伯虎), was '
#                     'a Chinese scholar, painter, calligrapher, and poet of the '
#                     'Ming dynasty period whose life story has become a part of '
#                     'popular lore. Even though he was born during the Ming '
#                     'dynasty, many of his paintings, especially those of '
#                     'people, were illustrated with elements from Pre-Tang to '
#                     'Song dynasty art.\r'
#                     ' Tang Yin is one of the most notable painters in the '
#                     'history of Chinese art. He is one of the "Four Masters of '
#                     'Ming dynasty” (Ming Si Jia), which also includes Shen '
#                     'Zhou (1427–1509), Wen Zhengming (1470–1559) and Qiu Ying '
#                     '(c. 1495-1552). His influence on the art of '
#                     'contemporaries, like Cai Han, is notable. Tang was also a '
#                     'talented poet, and together with his contemporaries Wen '
#                     'Zhengming, Zhu Yunming (1460–1526), and Xu Zhenqing, he '
#                     'was one of the "Four Literary Masters of the Wuzhong '
#                     'Region".\r'
#                     " Tang's eccentric lifestyle has prompted storytellers to "
#                     'immortalize him as a trickster character in Chinese '
#                     'folklore. In one such story, he falls in love with a '
#                     'slave girl whom he glimpses on the boat of a high '
#                     'official passing through Suzhou. He has himself sold as a '
#                     "slave to the official's household so that he may approach "
#                     'her. With the help of his friends, he eventually succeeds '
#                     'in bringing her home. This story prompted the playwright '
#                     'Three Words by Feng Menglong and the opera The Three '
#                     'Smiles.\r'
#                     ' Tang emerged from the vital merchant class of Suzhou, at '
#                     'a very low economic level of the son of a restaurant '
#                     'operator. Contrary to some accounts, he seems to have '
#                     'studied assiduously during his youth, paying little '
#                     'attention to the worldly charms. His genius, which would '
#                     'later gain him renown as the supreme talent of the '
#                     'Jiangnan area (Southern China), soon drew him into the '
#                     'wealthy, powerful, and talented circles of Suzhou. Wen '
#                     "Zhengming became his friend; Wen's father, Wen Lin "
#                     '(1445–99), acted as something of a patron, making the '
#                     'right connections for him.\r'
#                     ' He was a brilliant student and became the protégé of Wen '
#                     "Lin. His friends in Suzhou's scholarly circles included "
#                     'Shen Zhou, Wu Kuan (1436–1504) and Zhu Yunming. In 1498 '
#                     'Tang Yin came first in the provincial examinations in '
#                     'Nanjing, the second stage in the civil service '
#                     'examination ladder. The following year he went to the '
#                     'capital to sit the national examinations, but he and his '
#                     'friend Xu Jing (?- 1507) were accused of bribing the '
#                     'servant of one of the chief examiners to give them the '
#                     'examination questions in advance. All parties were '
#                     'jailed, and Tang Yin returned to Suzhou in disgrace, his '
#                     'justifiably high hopes for a distinguished civil service '
#                     'career dashed forever.\r'
#                     ' Denied further official progress, he pursued a life of '
#                     'pleasure and earned a living by selling his paintings. '
#                     'That mode of living brought him into disrepute with a '
#                     'later generation of artist-critics (for example, Dong '
#                     'Qichang) who felt that financial independence was vital '
#                     'to enable an artist to follow his own style and '
#                     'inspiration. While Tang is associated with paintings of '
#                     'feminine beauty, his paintings (especially landscapes) '
#                     'otherwise exhibit the same variety and expression of his '
#                     'peers and reveal a man of both artistic skill and '
#                     'profound insight.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Tang_Yin'}
# 2023-11-07 22:05:20 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/tang-yin>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1470',
#  'BirthPlace': 'Suzhou?, China',
#  'DeathDate': '1524',
#  'DeathPlace': None,
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3493,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Tang Yin ',
#  'Nationality': 'Chinese',
#  'OriginalName': 'Tang Yin (唐寅; Táng Yín; Tong Yan; Tang Bohu - 唐伯虎)',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/tang-yin',
#  'WikiDescription': 'Tang Yin (Chinese: 唐寅; pinyin: Táng Yín; Cantonese Yale: '
#                     'Tong Yan; 1470–1524), courtesy name Tang Bohu (唐伯虎), was '
#                     'a Chinese scholar, painter, calligrapher, and poet of the '
#                     'Ming dynasty period whose life story has become a part of '
#                     'popular lore. Even though he was born during the Ming '
#                     'dynasty, many of his paintings, especially those of '
#                     'people, were illustrated with elements from Pre-Tang to '
#                     'Song dynasty art.\r'
#                     ' Tang Yin is one of the most notable painters in the '
#                     'history of Chinese art. He is one of the "Four Masters of '
#                     'Ming dynasty” (Ming Si Jia), which also includes Shen '
#                     'Zhou (1427–1509), Wen Zhengming (1470–1559) and Qiu Ying '
#                     '(c. 1495-1552). His influence on the art of '
#                     'contemporaries, like Cai Han, is notable. Tang was also a '
#                     'talented poet, and together with his contemporaries Wen '
#                     'Zhengming, Zhu Yunming (1460–1526), and Xu Zhenqing, he '
#                     'was one of the "Four Literary Masters of the Wuzhong '
#                     'Region".\r'
#                     " Tang's eccentric lifestyle has prompted storytellers to "
#                     'immortalize him as a trickster character in Chinese '
#                     'folklore. In one such story, he falls in love with a '
#                     'slave girl whom he glimpses on the boat of a high '
#                     'official passing through Suzhou. He has himself sold as a '
#                     "slave to the official's household so that he may approach "
#                     'her. With the help of his friends, he eventually succeeds '
#                     'in bringing her home. This story prompted the playwright '
#                     'Three Words by Feng Menglong and the opera The Three '
#                     'Smiles.\r'
#                     ' Tang emerged from the vital merchant class of Suzhou, at '
#                     'a very low economic level of the son of a restaurant '
#                     'operator. Contrary to some accounts, he seems to have '
#                     'studied assiduously during his youth, paying little '
#                     'attention to the worldly charms. His genius, which would '
#                     'later gain him renown as the supreme talent of the '
#                     'Jiangnan area (Southern China), soon drew him into the '
#                     'wealthy, powerful, and talented circles of Suzhou. Wen '
#                     "Zhengming became his friend; Wen's father, Wen Lin "
#                     '(1445–99), acted as something of a patron, making the '
#                     'right connections for him.\r'
#                     ' He was a brilliant student and became the protégé of Wen '
#                     "Lin. His friends in Suzhou's scholarly circles included "
#                     'Shen Zhou, Wu Kuan (1436–1504) and Zhu Yunming. In 1498 '
#                     'Tang Yin came first in the provincial examinations in '
#                     'Nanjing, the second stage in the civil service '
#                     'examination ladder. The following year he went to the '
#                     'capital to sit the national examinations, but he and his '
#                     'friend Xu Jing (?- 1507) were accused of bribing the '
#                     'servant of one of the chief examiners to give them the '
#                     'examination questions in advance. All parties were '
#                     'jailed, and Tang Yin returned to Suzhou in disgrace, his '
#                     'justifiably high hopes for a distinguished civil service '
#                     'career dashed forever.\r'
#                     ' Denied further official progress, he pursued a life of '
#                     'pleasure and earned a living by selling his paintings. '
#                     'That mode of living brought him into disrepute with a '
#                     'later generation of artist-critics (for example, Dong '
#                     'Qichang) who felt that financial independence was vital '
#                     'to enable an artist to follow his own style and '
#                     'inspiration. While Tang is associated with paintings of '
#                     'feminine beauty, his paintings (especially landscapes) '
#                     'otherwise exhibit the same variety and expression of his '
#                     'peers and reveal a man of both artistic skill and '
#                     'profound insight.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Tang_Yin'}
# DEBUG:scrapy.core.engine:Crawled (200) <GET https://www.wikiart.org/en/ni-zan> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# 2023-11-07 22:05:20 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.wikiart.org/en/ni-zan> (referer: https://www.wikiart.org/en/artists-by-nation/chinese/text-list)
# DEBUG:scrapy.core.scraper:Scraped from <200 https://www.wikiart.org/en/fernando-botero>
# {'ActiveYears': None,
#  'ArtInstitutions': ['Real Academia de Bellas Artes de San Fernando, Madrid, '
#                      'Spain'],
#  'ArtMovements': ['Naïve Art (Primitivism)', 'Neo-Figurative Art'],
#  'BirthDate': 'April 19, 1932',
#  'BirthPlace': None,
#  'DeathDate': None,
#  'DeathPlace': None,
#  'Description': None,
#  'Fields': ['painting', 'sculpture'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3494,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Fernando Botero ',
#  'Nationality': 'Colombian',
#  'OriginalName': 'Fernando Botero Angulo',
#  'PaintingSchool': [],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/fernando-botero',
#  'WikiDescription': 'Fernando Botero Angulo (born 19 April 1932) is a '
#                     'Colombian figurative artist and sculptor. Born in '
#                     'Medellín, his signature style, also known as "Boterismo", '
#                     'depicts people and figures in large, exaggerated volume, '
#                     'which can represent political criticism or humor, '
#                     'depending on the piece. He is considered the most '
#                     'recognized and quoted living artist from Latin America, '
#                     'and his art can be found in highly visible places around '
#                     'the world, such as Park Avenue in New York City and the '
#                     'Champs-Élysées in Paris.\r'
#                     ' Self-titled "the most Colombian of Colombian artists" '
#                     'early on, he came to national prominence when he won the '
#                     'first prize at the Salón de Artistas Colombianos in 1958. '
#                     'Working most of the year in Paris, in the last three '
#                     'decades he has achieved international recognition for his '
#                     'paintings, drawings and sculpture, with exhibitions '
#                     'across the world. His art is collected by many major '
#                     'international museums, corporations, and private '
#                     'collectors. In 2012, he received the International '
#                     "Sculpture Center's Lifetime Achievement in Contemporary "
#                     'Sculpture Award.\r'
#                     ' Fernando Botero was born as the second of three sons to '
#                     'David Botero (1895–1936) and Flora Angulo (1898–1972) in '
#                     '1932. David Botero, a salesman who traveled by horseback, '
#                     'died of a heart attack when Fernando was four. His mother '
#                     'worked as a seamstress. An uncle took a major role in his '
#                     'life. Although isolated from art as presented in museums '
#                     'and other cultural institutes, Botero was influenced by '
#                     'the Baroque style of the colonial churches and the city '
#                     'life of Medellín while growing up.\r'
#                     ' He received his primary education in Antioquia Ateneo '
#                     'and, thanks to a scholarship, he continued his secondary '
#                     'education at the Jesuit School of Bolívar. In 1944, '
# ...
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3520,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Shen Zhou ',
#  'Nationality': 'Chinese',
#  'OriginalName': 'Shěn Zhōu (沈周)',
#  'PaintingSchool': ['Wu School'],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/shen-zhou',
#  'WikiDescription': 'Shen Zhou (Chinese: 沈周; pinyin: Shěn Zhōu, 1427–1509), '
#                     "courtesy name Qi'nan (启南) and Shitian (石田), was a Chinese "
#                     'painter in the Ming dynasty.\r'
#                     ' Shen Zhou was born into a wealthy family in Xiangcheng, '
#                     'near the thriving city of Suzhou, in the Jiangsu '
#                     "province, China. His genealogy traces his family's wealth "
#                     "to the late Yuan period, but only as far as Shen's "
#                     'paternal great-grandfather, Shen Liang-ch’en, who became '
#                     'a wealthy landowner following the dissolution of Mongol '
#                     'rule. After the collapse of the Yuan and the emergence of '
#                     'the new Ming dynasty, the position of tax collector was '
#                     'assigned to the head of the Shen family, under the Hongwu '
#                     "emperor's new lijia system. This steadily and amply "
#                     "increased the family's wealth, while freeing Shen "
#                     "Liang-ch’en's male descendants from obligatory careers as "
#                     'Ming officials, and allowing them to live the majority of '
#                     'their lives as retired scholar-artists. Upon the death of '
#                     'his father, Shen Heng-chi, Shen Zhou decided to forgo '
#                     'official examinations and devote his life to the care of '
#                     'his widowed mother, Chang Su-wan. It is probable that he '
#                     'never intended to become an official, but refrained from '
#                     'making this obvious until his father had died. He thus '
#                     'renounced the life of official service while still '
#                     'preserving his reputation in an enduring act of filial '
#                     'piety. In this way, he was able to live a reclusive life, '
#                     'free of responsibility (except that of caring for his '
#                     'mother), and devote his time to artwork, socializing, and '
#                     'monastic contemplation of the natural world around him.\r'
#                     ' Shen Zhou lived at a pivotal point in the history of '
#                     'Chinese painting, and contributed greatly to the artistic '
#                     'tradition of China, founding the new Wu School in Suzhou. '
#                     'Under the Yuan dynasty (1279-1368), painters had '
#                     'practiced with relative freedom, cultivating a more '
#                     '“individualist,” innovative approach to art that deviated '
#                     'noticeably from the more superficial style of the Song '
#                     'masters who preceded them. However, at the outset of the '
#                     'Ming, the Hongwu emperor (reg 1368-1398) decided to '
#                     'import the existing master painters to his court in '
#                     'Nanjing, where he had the ability to cultivate their '
#                     'styles to conform to the paintings of the Song masters. '
#                     'As Hongwu was notorious for his attempts to marginalize '
#                     'and persecute the scholar class, this was seen as an '
#                     'attempt to banish the gentry’s influence from the arts. '
#                     'The dominant style of the Ming court painters was called '
#                     'the Zhe School. However, following the ascension of the '
#                     'Yongle emperor (reg 1403-1424), the capital was moved '
#                     'from Nanjing to Beijing, putting a large distance between '
#                     'imperial influence and the city of Suzhou. These new '
#                     'conditions led to the rise of the Wu School of painting, '
#                     'a somewhat subversive style that revived the ideal of the '
#                     'inspired scholar-painter in Ming China.\r'
#                     ' Shen Zhou’s scholarly upbringing and artistic training '
#                     "had instilled in him a reverence for China's historical "
#                     'tradition that influenced both his life and his art from '
#                     'an early age. He was accomplished in history and the '
#                     'classics, and his paintings reveal a disciplined '
#                     "obedience to the styles of the Yuan dynasty, to China's "
#                     'history, and to the orthodox Confucianism that he '
#                     'embodied in his filial life. He is most famous for his '
#                     'landscapes and for his "boneless" renderings of flowers, '
#                     'which are meticulously created in the style of the Yuan '
#                     'masters. However, he did not always paint within strict '
#                     'boundaries. His inherited prosperity afforded him the '
#                     'luxury of painting independently of patrons, and he did '
#                     'so in a way that, while revealing his historical '
#                     'influence, was uniquely his own. Shen possessed a large '
#                     'collection of paintings from the late Yuan and early '
#                     'Ming, which he and his scholar-painter colleagues used as '
#                     'models in forging the revivalist approach of the Wu '
#                     'style. He frequently combined experimental elements with '
#                     'the more rigid styles of the Yuan masters. Much of his '
#                     'work was done in collaboration with others, combining '
#                     'painting, poetry, and calligraphy at gatherings with his '
#                     'literati friends. It was upon these ideals that his Wu '
#                     'School was founded. For Wu painters, painting was a '
#                     'meditation, rather than an occupation. Shen Zhou never '
#                     'coveted his paintings, although they were frequently '
#                     "coveted and imitated by others. Through Shen Zhou's eyes, "
#                     'a painting was not a commodity, but the very extension of '
#                     'the painter himself.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Shen_Zhou'}
# 2023-11-07 22:05:25 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.wikiart.org/en/shen-zhou>
# {'ActiveYears': None,
#  'ArtInstitutions': [],
#  'ArtMovements': ['Ming Dynasty (1368–1644)'],
#  'BirthDate': '1427',
#  'BirthPlace': 'Xiangcheng, Jiangsu, China',
#  'DeathDate': '1509',
#  'DeathPlace': 'China',
#  'Description': None,
#  'Fields': ['painting'],
#  'FriendsAndCoworkers': [],
#  'Genres': [],
#  'Id': 3520,
#  'InfluencedBy': [],
#  'InfluencedOn': [],
#  'Name': 'Shen Zhou ',
#  'Nationality': 'Chinese',
#  'OriginalName': 'Shěn Zhōu (沈周)',
#  'PaintingSchool': ['Wu School'],
#  'Pupils': [],
#  'Teachers': [],
#  'URL': 'https://www.wikiart.org/en/shen-zhou',
#  'WikiDescription': 'Shen Zhou (Chinese: 沈周; pinyin: Shěn Zhōu, 1427–1509), '
#                     "courtesy name Qi'nan (启南) and Shitian (石田), was a Chinese "
#                     'painter in the Ming dynasty.\r'
#                     ' Shen Zhou was born into a wealthy family in Xiangcheng, '
#                     'near the thriving city of Suzhou, in the Jiangsu '
#                     "province, China. His genealogy traces his family's wealth "
#                     "to the late Yuan period, but only as far as Shen's "
#                     'paternal great-grandfather, Shen Liang-ch’en, who became '
#                     'a wealthy landowner following the dissolution of Mongol '
#                     'rule. After the collapse of the Yuan and the emergence of '
#                     'the new Ming dynasty, the position of tax collector was '
#                     'assigned to the head of the Shen family, under the Hongwu '
#                     "emperor's new lijia system. This steadily and amply "
#                     "increased the family's wealth, while freeing Shen "
#                     "Liang-ch’en's male descendants from obligatory careers as "
#                     'Ming officials, and allowing them to live the majority of '
#                     'their lives as retired scholar-artists. Upon the death of '
#                     'his father, Shen Heng-chi, Shen Zhou decided to forgo '
#                     'official examinations and devote his life to the care of '
#                     'his widowed mother, Chang Su-wan. It is probable that he '
#                     'never intended to become an official, but refrained from '
#                     'making this obvious until his father had died. He thus '
#                     'renounced the life of official service while still '
#                     'preserving his reputation in an enduring act of filial '
#                     'piety. In this way, he was able to live a reclusive life, '
#                     'free of responsibility (except that of caring for his '
#                     'mother), and devote his time to artwork, socializing, and '
#                     'monastic contemplation of the natural world around him.\r'
#                     ' Shen Zhou lived at a pivotal point in the history of '
#                     'Chinese painting, and contributed greatly to the artistic '
#                     'tradition of China, founding the new Wu School in Suzhou. '
#                     'Under the Yuan dynasty (1279-1368), painters had '
#                     'practiced with relative freedom, cultivating a more '
#                     '“individualist,” innovative approach to art that deviated '
#                     'noticeably from the more superficial style of the Song '
#                     'masters who preceded them. However, at the outset of the '
#                     'Ming, the Hongwu emperor (reg 1368-1398) decided to '
#                     'import the existing master painters to his court in '
#                     'Nanjing, where he had the ability to cultivate their '
#                     'styles to conform to the paintings of the Song masters. '
#                     'As Hongwu was notorious for his attempts to marginalize '
#                     'and persecute the scholar class, this was seen as an '
#                     'attempt to banish the gentry’s influence from the arts. '
#                     'The dominant style of the Ming court painters was called '
#                     'the Zhe School. However, following the ascension of the '
#                     'Yongle emperor (reg 1403-1424), the capital was moved '
#                     'from Nanjing to Beijing, putting a large distance between '
#                     'imperial influence and the city of Suzhou. These new '
#                     'conditions led to the rise of the Wu School of painting, '
#                     'a somewhat subversive style that revived the ideal of the '
#                     'inspired scholar-painter in Ming China.\r'
#                     ' Shen Zhou’s scholarly upbringing and artistic training '
#                     "had instilled in him a reverence for China's historical "
#                     'tradition that influenced both his life and his art from '
#                     'an early age. He was accomplished in history and the '
#                     'classics, and his paintings reveal a disciplined '
#                     "obedience to the styles of the Yuan dynasty, to China's "
#                     'history, and to the orthodox Confucianism that he '
#                     'embodied in his filial life. He is most famous for his '
#                     'landscapes and for his "boneless" renderings of flowers, '
#                     'which are meticulously created in the style of the Yuan '
#                     'masters. However, he did not always paint within strict '
#                     'boundaries. His inherited prosperity afforded him the '
#                     'luxury of painting independently of patrons, and he did '
#                     'so in a way that, while revealing his historical '
#                     'influence, was uniquely his own. Shen possessed a large '
#                     'collection of paintings from the late Yuan and early '
#                     'Ming, which he and his scholar-painter colleagues used as '
#                     'models in forging the revivalist approach of the Wu '
#                     'style. He frequently combined experimental elements with '
#                     'the more rigid styles of the Yuan masters. Much of his '
#                     'work was done in collaboration with others, combining '
#                     'painting, poetry, and calligraphy at gatherings with his '
#                     'literati friends. It was upon these ideals that his Wu '
#                     'School was founded. For Wu painters, painting was a '
#                     'meditation, rather than an occupation. Shen Zhou never '
#                     'coveted his paintings, although they were frequently '
#                     "coveted and imitated by others. Through Shen Zhou's eyes, "
#                     'a painting was not a commodity, but the very extension of '
#                     'the painter himself.',
#  'WikipediaLink': 'http://en.wikipedia.org/wiki/Shen_Zhou'}
# INFO:scrapy.core.engine:Closing spider (finished)
# 2023-11-07 22:05:25 [scrapy.core.engine] INFO: Closing spider (finished)
# INFO:scrapy.extensions.feedexport:Stored csv feed (3521 items) in: artists.csv
# 2023-11-07 22:05:25 [scrapy.extensions.feedexport] INFO: Stored csv feed (3521 items) in: artists.csv
# INFO:scrapy.statscollectors:Dumping Scrapy stats:
# {'downloader/request_bytes': 1944402,
#  'downloader/request_count': 3628,
#  'downloader/request_method_count/GET': 3628,
#  'downloader/response_bytes': 182403758,
#  'downloader/response_count': 3628,
#  'downloader/response_status_count/200': 3628,
#  'dupefilter/filtered': 686,
#  'elapsed_time_seconds': 570.853543,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 7, 22, 5, 25, 298112, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1272194435,
#  'httpcompression/response_count': 3628,
#  'item_scraped_count': 3521,
#  'log_count/DEBUG': 7151,
#  'log_count/INFO': 20,
#  'memusage/max': 241123328,
#  'memusage/startup': 141815808,
#  'request_depth_max': 2,
#  'response_received_count': 3628,
#  'scheduler/dequeued': 3628,
#  'scheduler/dequeued/memory': 3628,
#  'scheduler/enqueued': 3628,
#  'scheduler/enqueued/memory': 3628,
#  'start_time': datetime.datetime(2023, 11, 7, 21, 55, 54, 444569, tzinfo=datetime.timezone.utc)}
# 2023-11-07 22:05:25 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 1944402,
#  'downloader/request_count': 3628,
#  'downloader/request_method_count/GET': 3628,
#  'downloader/response_bytes': 182403758,
#  'downloader/response_count': 3628,
#  'downloader/response_status_count/200': 3628,
#  'dupefilter/filtered': 686,
#  'elapsed_time_seconds': 570.853543,
#  'feedexport/success_count/FileFeedStorage': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 11, 7, 22, 5, 25, 298112, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 1272194435,
#  'httpcompression/response_count': 3628,
#  'item_scraped_count': 3521,
#  'log_count/DEBUG': 7151,
#  'log_count/INFO': 20,
#  'memusage/max': 241123328,
#  'memusage/startup': 141815808,
#  'request_depth_max': 2,
#  'response_received_count': 3628,
#  'scheduler/dequeued': 3628,
#  'scheduler/dequeued/memory': 3628,
#  'scheduler/enqueued': 3628,
#  'scheduler/enqueued/memory': 3628,
#  'start_time': datetime.datetime(2023, 11, 7, 21, 55, 54, 444569, tzinfo=datetime.timezone.utc)}
# INFO:scrapy.core.engine:Spider closed (finished)
# 2023-11-07 22:05:25 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
import pandas as pd
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# 2023-11-08 00:10:25 [numexpr.utils] INFO: NumExpr defaulting to 2 threads.

# %%
artist_info = pd.read_csv("artists.csv")

# %%
list(artist_info['Name'].str.strip().str.lower())
# Out:
# ['sm sultan',
#  'agim sulaj',
#  'gennady mironov',
#  '[ a y s h ]',
#  'gazmend freitag',
#  'tahir salahov',
#  'ivan milev',
#  'soltan soltanlı',
#  'branko bačanović',
#  'thiago boecan',
#  'rodrigo franzao',
#  'banksy',
#  'marianne stokes',
#  'matthias laurenz gräff',
#  'alberto pereira',
#  'ashley bickerton',
#  'gerwald rockenschaub',
#  'georg miciú',
#  'heimo zobernig',
#  'francis a. willey',
#  'nzante spee',
#  'gisela colon',
#  'hifa cybe',
#  'manfred kielnhofer',
#  'david burdeny',
#  'christopher willard',
#  'jessica stockholder',
#  'christian eckart',
#  'barbara mcgivern',
#  'charles gibbons',
#  'landon mackenzie',
#  'kent monkman',
#  'richard hambleton',
#  'wanda koop',
#  'tony scherman',
#  'amir baradaran',
#  'zainul abedin',
#  'ken danby',
#  'ivan eyre',
#  'haralampi g. oroschakoff',
#  'claude tousignant',
#  'yves gaucher',
#  'mary pratt',
#  'marjan eggermont',
#  'armand vaillancourt',
#  'jean-paul jerome',
#  'rashid al khalifa',
#  'marcel barbeau',
#  'mimi parent',
#  'kazuo nakamura',
#  'jean-paul riopelle',
#  'dorothea rockburne',
#  'norman zammitt',
#  'alex colville',
#  'betty goodwin',
#  'norval morrisseau',
#  'fernand leduc',
#  'ronald bladen',
#  'rené marcil',
#  'ralston crawford',
#  'maud lewis',
#  'jean paul lemieux',
#  'prudence heward',
#  'franklin carmichael',
#  'jack bush',
#  'lawren harris',
#  'a.y. jackson',
#  'agnes martin',
#  'frederick varley',
#  'tom thomson',
#  'jean benoit',
#  'emily carr',
#  'paul peel',
#  'robert harris',
#  'jacqueline winsor',
#  'edward mitchell bannister',
#  'paul kane',
#  'homer watson',
#  'anselm kiefer',
#  'christian attersee',
#  'hanno karlhuber',
#  'ernst fuchs',
#  'arnulf rainer',
#  'friedensreich hundertwasser',
#  'otto muehl',
#  'karl prantl',
#  'greta freist',
#  'wolfgang paalen',
#  'werner berg',
#  'egon schiele',
#  'oskar kokoschka',
#  'max oppenheimer',
#  'richard gerstl',
#  'alfred kubin',
#  'franz sedlacek',
#  'raphael kirchner',
#  'bertold löffler',
#  'leopoldo metlicovitz',
#  'koloman moser',
#  'albin egger-lienz',
#  'max kurzweil',
#  'heinrich kuhn',
#  'alfred roller',
#  'heinrich lefler',
#  'gustav klimt',
#  'rudolf ernst',
#  'joseph urbania',
#  'francesco beda',
#  'gabriel von max',
#  'anton romako',
#  'ludwig passini',
#  'ernest lawson',
#  'george folingsby',
#  'felix philipp kanitz',
#  'constantin daniel rosenthal',
#  'eugene de blaas',
#  'rudolf von alt',
#  'eugene von guerard',
#  'miriam schapiro',
#  'johann nepomuk passini',
#  'johann baptist clarot',
#  'clarence gagnon',
#  'alexander clarot',
#  'ferdinand georg waldmüller',
#  'frank johnston',
#  'heinrich papin',
#  'joseph anton koch',
#  'barbara krafft',
#  'guido molinari',
#  'eduardo berliner',
#  'sidney amaral',
#  'paula klien',
#  'josef kriehuber',
#  'romero britto',
#  'vik muniz',
#  'beatriz milhazes',
#  'cildo meireles',
#  'miguel rio branco',
#  'claudio tozzi',
#  'helio oiticica',
#  'rubem ludolf',
#  'peter fendi',
#  'oyvind fahlstrom',
#  'lygia pape',
#  'ernesto neto',
#  'manabu mabe',
#  'luis sacilotto',
#  'ivan serpa',
#  'adriana varejão',
#  'almir mavignier',
#  'amilcar de castro',
#  'abraham palatnik',
#  'aldemir martins',
#  'mira schendel',
#  'lygia clark',
#  'mario zanini',
#  'arthur nísio',
#  'candido portinari',
#  'aldo locatelli',
#  'lothar charoux',
#  'guido viaro',
#  'alfredo volpi',
#  'jose pancetti',
#  'jordão de oliveira',
#  'victor brecheret',
#  'lasar segall',
#  'tarsila do amaral',
#  'georgina de albuquerque',
#  'joseph kreutzinger',
#  'eliseu visconti',
#  'alfredo andersen',
#  'rodolfo amoedo',
#  'joseph binder',
#  'pedro américo',
#  'victor meirelles',
#  'alberto da veiga guignard',
#  'mestre ataíde',
#  'august von pettenkofen',
#  'anita malfatti',
#  'vajiha samadova',
#  'simplício rodrigues de sá',
#  'jose ferraz de almeida junior',
#  'emiliano di cavalcanti',
#  'boushra yahya almutawakel',
#  'christo and jeanne-claude',
#  'radi nedelchev',
#  'boyukagha mirzazade',
#  'omer mujadžić',
#  'azim azimzade',
#  'georgi kovachev',
#  'mahmud taghiyev',
#  'dora boneva',
#  'georges papazoff',
#  'mana parpulova',
#  'georgi mashev',
#  'simeon velkov',
#  'dobri dobrev',
#  'sirak skitnik',
#  'vladimir dimitrov',
#  'vera nedkova',
#  'anton mitov',
#  'maria stolarova',
#  'nikola tanev',
#  'orthodox icons',
#  'ancient greek pottery',
#  'leon tarasewicz',
#  'ivan mrkviсka',
#  'chaim soutine',
#  'michel kikoine',
#  'pinchus kremegne',
#  'marc chagall',
#  'jules pascin',
#  'wladyslaw strzeminski',
#  'vitold byalynitsky-birulya',
#  'byzantine mosaics',
#  'apollinary goravsky',
#  'eugeniusz zak',
#  'haralampi tachev',
#  'mary jane ansell',
#  'noma bar',
#  'abraham manievich',
#  'david thorpe',
#  'chris ofili',
#  'jenny saville',
#  'leon bakst',
#  'joe machine',
#  'sarah morris',
#  'ian davenport',
#  'angela bulloch',
#  'liam gillick',
#  'jim lambie',
#  'tracey emin',
#  'martin creed',
#  'rachel whiteread',
#  'yinka shonibare',
#  'gary hume',
#  'callum innes',
#  'william balthazar rose',
#  'peter doig',
#  'deborah azzopardi',
#  'julian opie',
#  '3d',
#  'damien hirst',
#  'glenn brown',
#  'joan tuset',
#  'carles delclaux is',
#  'joan hernandez pijuan',
#  'joan ponc',
#  'alejandro cabeza',
#  'antoni tapies',
#  'albert rafols-casamada',
#  'alejandro obregon',
#  'carlos nadal',
#  'esteban frances',
#  'emilio grau sala',
#  'pablo rey',
#  'salvador dali',
#  'sattar bahlulzade',
#  'david batchelor',
#  'anish kapoor',
#  'linder',
#  'martin yeoman',
#  'jeremy henderson',
#  'modest cuixart',
#  'billy childish',
#  'jack vettriano',
#  'mona hatoum',
#  'remedios varo',
#  'giuliana lazzerini',
#  'antony gormley',
#  'richard deacon',
#  'bill woodrow',
#  'lorenzo belenguer',
#  'godfrey blow',
#  'richard spare',
#  'alison wilding',
#  'cornelia parker',
#  'brian froud',
#  'kit williams',
#  'gary wragg',
#  'richard long',
#  'john hilliard',
#  'carmen osés hidalgo',
#  'mel ramsden',
#  'peter phillips',
#  'david bowie',
#  'pauline boty',
#  'phyllida barlow',
#  'alan lee',
#  'paul neagu',
#  'alan charlton',
#  'david hockney',
#  'norman ackroyd',
#  'sue coe',
#  'tess jaray',
#  'mark lancaster',
#  'frank bowling',
#  'tim scott',
#  'derek boshier',
#  'iain baxter&',
#  'julio gonzalez',
#  'ramon casas',
#  'joan brull',
#  'santiago rusinol',
#  'allen jones',
#  'marià fortuny',
#  'hyacinthe rigaud',
#  'joan miro',
#  'william tucker',
#  'francesco ribalta',
#  'john hoyland',
#  'jeremy moon',
#  'david annesley',
#  'paula rego',
#  'phillip king',
#  'basil beattie',
#  'francesc masriera',
#  'howard hodgkin',
#  'bob law',
#  'malcolm morley',
#  'patrick caulfield',
#  'bridget riley',
#  'patrick procktor',
#  'john miller',
#  'gillian ayres',
#  'peter joseph',
#  'joe tilson',
#  'peter blake',
#  'bernard cohen',
#  'anthony caro',
#  'desmond morris',
#  'eduardo paolozzi',
#  'john bratby',
#  'albert irvin',
#  'fred yates',
#  'frank auerbach',
#  'william turnbull',
#  'leonora carrington',
#  'brion gysin',
#  'lucian freud',
#  'mary fedden',
#  'reg butler',
#  'william scott',
#  'conroy maddox',
#  'josef herman',
#  'graham bell',
#  'francis bacon',
#  'victor pasmore',
#  'oliver kilbourn',
#  'graham sutherland',
#  'richard hamilton',
#  'richard eurich',
#  'charles tunnicliffe',
#  'christopher wood',
#  'eileen agar',
#  'clarice cliff',
#  'winifred knights',
#  'terry frost',
#  'jock macdonald',
#  'eric ravilious',
#  'patrick heron',
#  'stanley spencer',
#  'richard smith',
#  'winifred nicholson',
#  'edward wadsworth',
#  'leon underwood',
#  'peter laszlo peri',
#  'paul nash',
#  'marc vaux',
#  'henry moore',
#  'arthur lismer',
#  'c. r. w. nevinson',
#  'ethel léontine gabain',
#  'edmund dulac',
#  'michael bolus',
#  'eric gill',
#  'jacob epstein',
#  'grace pailthorpe',
#  'matthew smith',
#  'vanessa bell',
#  'william orpen',
#  'austin osman spare',
#  'augustus john',
#  'lady frieda harris',
#  'david bomberg',
#  'laura knight',
#  'william russell flint',
#  'john duncan fergusson',
#  'frances macdonald',
#  'j. e. h. macdonald',
#  'cyril power',
#  'max meldrum',
#  'ben nicholson',
#  'ethel carrick',
#  'byam shaw',
#  'winston churchill',
#  'algernon talmage',
#  'harry phelan gibb',
#  'aubrey beardsley',
#  'frances hodgkins',
#  'charles rennie mackintosh',
#  'charles robinson',
#  'alvin langdon coburn',
#  'beatrix potter',
#  'roger fry',
#  'l. s. lowry',
#  'arthur lowe',
#  'margaret macdonald',
#  'albert julius olsson',
#  'herbert james draper',
#  'henry tonks',
#  'gwen john',
#  'philip wilson steer',
#  'solomon joseph solomon',
#  'louis wain',
#  'archibald thorburn',
#  'walter sickert',
#  'charles spencelayh',
#  'john henderson',
#  'william logsdail',
#  'samuel peploe',
#  'henry scott tuke',
#  'arthur rackham',
#  'william barnes wollen',
#  'herbert gustave schmalz (herbert carmichael)',
#  'richard caton woodville jr.',
#  'george henry',
#  'alfred wallis',
#  'william gilbert foster',
#  'richard jack',
#  'arne quinze',
#  'katrien de blauwer',
#  'carsten holler',
#  'luc tuymans',
#  'evelyn de morgan',
#  'evelyne axell',
#  'walter leblanc',
#  'william sidney cooper',
#  'charles william mitchell',
#  'tom scott',
#  'frank dicksee',
#  'david james',
#  'jef verheyen',
#  'john william godward',
#  'frederick george cotman',
#  'john collier',
#  'henry herbert la thangue',
#  'edward robert hughes',
#  'john william waterhouse',
#  'eleanor fortescue-brickdale',
#  'frederick morgan',
#  "ilse d'hollander",
#  'walter crane',
#  'james campbell noble',
#  'joseph farquharson',
#  'alfred parsons',
#  'luke fildes',
#  'heywood hardy',
#  'john varley ii',
#  'albert joseph moore',
#  'simeon solomon',
#  'augustus edwin mulready',
#  'marcus stone',
#  'ralph hedley',
#  'alfred sisley',
#  'john pettie',
#  'john lee',
#  'briton riviere',
#  'laslett john pott',
#  'helen augusta hamburger',
#  'john atkinson grimshaw',
#  'elizabeth thompson',
#  'alfred concanen',
#  'robert bateman',
#  'raoul de keyser',
#  'pierre alechinsky',
#  'marcel broodthaers',
#  'james charles',
#  'roger raveel',
#  'william morris',
#  'pol bury',
#  'louis van lint',
#  'marcel marien',
#  'jan cox',
#  'henri michaux',
#  'rene magritte',
#  'paul delvaux',
#  'david bates',
#  'edward r. taylor',
#  'edward poynter',
#  'leon spilliaert',
#  'georges vantongerloo',
#  'michel seuphor',
#  'victor servranckx',
#  'gustave singier',
#  'georges lemmen',
#  'frank holl',
#  'henry van de velde',
#  'rik wouters',
#  'willy schlobach',
#  'firmin baes',
#  'gustave de smet',
#  'xavier mellery',
#  'leo steel',
#  'theo van rysselberghe',
#  'james ensor',
#  'fernand khnopff',
#  'jean-françois portaels',
#  'armand henrion',
#  'petrus van schendel',
#  'gustaf wappers',
#  'pieter van hanselaere',
#  'bartholomeus spranger',
#  'edward burne-jones',
#  'henry william banks davis',
#  'lewis carroll',
#  'arthur hughes',
#  'felicien rops',
#  'frederic leighton',
#  'alfred william finch',
#  "john o'connor",
#  'alfred stevens',
#  'charles hermans',
#  'john roddam spencer stanhope',
#  'dante gabriel rossetti',
#  'frederick sandys',
#  'james campbell',
#  'william holman hunt',
#  'roberto rive',
#  'james webb',
#  'william simpson',
#  'sophie gengembre anderson',
#  'james archer',
#  'ford madox brown',
#  'edward ladell',
#  'john everett millais',
#  'john ruskin',
#  'thomas francis dicksee',
#  'marianne north',
#  'john leech',
#  'george frederick watts',
#  'julia margaret cameron',
#  'john absolon',
#  'thomas stuart smith',
#  'henry moore',
#  'edward lear',
#  'owen jones',
#  'david scott',
#  'carl haag',
#  'samuel palmer',
#  'édouard de bièfve',
#  'robert william buss',
#  'bernard van orley',
#  'franz richard unterberger',
#  'richard parkes bonington',
#  'edwin henry landseer',
#  'john frederick lewis',
#  'george philip reinagle',
#  'john wilson carmichael',
#  'penry williams',
#  'david roberts',
#  'christina robertson',
#  'william leighton leitch',
#  'george harvey',
#  'william henry hunt',
#  'thomas jones barker',
#  'richard dadd',
#  'william shayer',
#  'john martin',
#  'thomas sully',
#  'david cox',
#  'george hemming mason',
#  'george dawe',
#  'john varley',
#  'john bradley',
#  'john constable',
#  'j.m.w. turner',
#  'john frederick herring sr.',
#  'charles martin powell',
#  'william collins',
#  'charles turner',
#  'james ward',
#  'thomas girtin',
#  'john crome',
#  'john glover',
#  'george morland',
#  'lemuel francis abbott',
#  'john hoppner',
#  'william blake',
#  'john jackson',
#  'john flaxman',
#  'william hamilton',
#  'david wilkie',
#  'david allan',
#  'thomas hardy',
#  'benjamin west',
#  'george romney',
#  'joseph wright',
#  'john russell',
#  'william williams',
#  'thomas jones',
#  'joshua reynolds',
#  'john gibson',
#  'richard wilson',
#  'henry raeburn',
#  'david morier',
#  'george lambert',
#  'william hogarth',
#  'gavin hamilton',
#  'mary beale',
#  'john simpson',
#  'isaac fuller',
#  'nicholas hilliard',
#  'romanesque architecture',
#  'viking art',
#  'ancient greek painting and sculpture',
#  'william dobson',
#  'john riley',
#  'george stubbs',
#  'allan ramsay',
#  'thomas lawrence',
#  'justin earl grant',
#  'luis camnitzer',
#  'ibrahim yıldız',
#  'rirkrit tiravanija',
#  'saul zanolari',
#  'thomas gainsborough',
#  'simon stalenhag',
#  'raúl berzosa',
#  'chul hyun ahn',
#  'ibrahim salahi',
#  'cameron platter',
#  'paul du toit',
#  'marlene dumas',
#  'christo coetzee',
#  'stanley pinker',
#  'gerard sekoto',
#  'george pemba',
#  'walter battiss',
#  'irma stern',
#  'vasan sitthiket',
#  'gregoire boonzaier',
#  'maggie laubser',
#  'pieter wenning',
#  'moon pil shim',
#  'hong song-dam',
#  'ha chong-hyun',
#  'nam june paik',
#  'park seo-bo',
#  'kim tschang-yeul',
#  'se-ok suh',
#  'louay kayyali',
#  'yun hyong–keun',
#  'owon',
#  'do ho suh',
#  'sami gattoufi',
#  'carmen delaco',
#  'shin yoon-bok',
#  'nieves mingueza',
#  'patxi xabier lezama perier',
#  'francis naranjo',
#  'inigo manglano-ovalle',
#  'consuelo hernández',
#  'requena nozal',
#  'soledad sevilla',
#  'eduardo arroyo',
#  'jorge castillo',
#  'teddy cobeña',
#  'manuel rivera',
#  'jose manuel capuletti',
#  'martin chirino',
#  'lee ufan',
#  'eduardo chillida',
#  'jesús meneses del barco',
#  'antonio povedano',
#  'antonio bueno',
#  'francisco serra andrés',
#  'etchingroom1',
#  'babak-matveev',
#  'luis feito',
#  'pablo palazuelo',
#  'stepan ryabchenko',
#  'davyd chychkan',
#  'lucy ivanova',
#  'oswaldo vigas',
#  'danil nemirovsky',
#  'antonio lopez garcia',
#  'gego',
#  'armando reveron',
#  'lara almarcegui',
#  'kinder album',
#  'jesus rafael soto',
#  'arturo michelena',
#  'tran van can',
#  'le pho',
#  'luchita hurtado',
#  'ilya isupov',
#  'vlada ralko',
#  'carlos cruz-diez',
#  'oleg holosiy',
#  'danh vō',
#  'kateryna lysovenko',
#  'alexander roitburd',
#  'marisol escobar',
#  'oleksandr hnylyzkyj',
#  'oleh denysenko',
#  'arsen savadov',
#  'sergey belik',
#  'oleksandr aksinin',
#  'tiberiy szilvashi',
#  'volodymyr loboda',
#  'alevtyna kakhidze',
#  'vudon baklytsky',
#  'mykhailo vainshtein',
#  'vasiliy ryabchenko',
#  'zoe lerman',
#  'vilen barsky',
#  'georgyi yakutovytch',
#  'alla horska',
#  'yuriy khymych',
#  'hryhorii havrylenko',
#  'viktor shatalin',
#  'valerii lamakh',
#  'pavlo makov',
#  'sergei parajanov',
#  'karlo zvirynsky',
#  'dmytro kavsan',
#  'ivan-valentyn zadorozhny',
#  'oleh sokolov',
#  'valeria trubina',
#  'victor puzyrkov',
#  'serhij schyschko',
#  'bui xuan phai',
#  'tetyana yablonska',
#  'volodymyr bondarenko',
#  'sergiy grigoriev',
#  'roman selsky',
#  'boris margo',
#  'oleksandr pashenko',
#  'maria primachenko',
#  'margit selska',
#  'sergey ryabchenko',
#  'kateryna bilokur',
#  'leonid muchnyk',
#  'cassandre',
#  'alexander khvostenko-khvostov',
#  'henryk streng',
#  'vasyl yermylov',
#  'vsevolod maksymovych',
#  'anatol petrytsky',
#  'vasyl sedlyar',
#  'adalbert erdeli',
#  'el lissitzky',
#  'nathan altman',
#  'victor palmov',
#  'olexandr archipenko',
#  'ivan marchuk',
#  'vladimir tatlin',
#  'sonia delaunay',
#  'victor zaretsky',
#  'zinaida serebriakova',
#  'vadym meller',
#  'valentin khrushch',
#  'mykhailo boychuk',
#  'david burliuk',
#  'bruno schulz',
#  'heorhiy narbut',
#  'fedir krychevsky',
#  'kazimir malevich',
#  'oleksandr bogomazov',
#  'ilarion pleshynskyi',
#  'oleksandr murashko',
#  'oleksa novakivskyi',
#  'vasyl kasiyan',
#  'nikolai kuznetsov',
#  'mykola samokysh',
#  'mykola yaroshenko',
#  'mykola murashko',
#  'arkhyp kuindzhi',
#  'volodymyr orlovsky',
#  'nikolai ge',
#  'wilhelm kotarbinski',
#  'vladimir borovikovsky',
#  'dmitry levitzky',
#  'taras shevchenko',
#  'aleksandra ekster',
#  'ivan rutkovych',
#  'vela zanetti',
#  'jose guerrero',
#  'rafael zabaleta',
#  'oscar dominguez',
#  'yov kondzelevych',
#  'arturo souto',
#  'maruja mallo',
#  'angel planells',
#  'carlos saenz de tejada',
#  'marie bashkirtseff',
#  'pierre daura',
#  'esteban vicente',
#  'juan gris',
#  'maria blanchard',
#  'johann georg pinzel',
#  'pablo picasso',
#  'josé garnelo',
#  'joaquín sorolla',
#  'armando montaner valdueza',
#  'luis ricardo falero',
#  'julio romero de torres',
#  'petro kholodny (elder)',
#  'joaquín agrasot',
#  'martín rico y ortega',
#  'jose gutierrez solana',
#  'achille zo',
#  'luis de madrazo y kuntz',
#  'joaquín domínguez bécquer',
#  'alexis gritchenko',
#  'leonardo alenza',
#  'narcisse-virgilio diaz',
#  'jenaro pérez villaamil',
#  'antonio cabral bejarano',
#  'rafael garcía hispaleto (el hispaleto)',
#  'francisco goya',
#  'joaquin manuel fernandez cruzado',
#  'rosario weiss zorrilla',
#  'luis paret y alcazar',
#  'giuseppe maria crespi',
#  'karpo trokhymenko',
#  'francisco bayeu y subias',
#  'josefa de obidos',
#  'juan de valdes leal',
#  'bartolome esteban murillo',
#  'alonzo cano',
#  'diego velazquez',
#  'claudio coello',
#  'juan van der hamen',
#  'jusepe de ribera',
#  'francisco de zurbaran',
#  'francisco herrera',
#  'francisco pacheco',
#  'raimundo de madrazo',
#  'mariano benlliure',
#  'bartolome bermejo',
#  'juan bautista maíno',
#  'ende',
#  'erik sigerud',
#  'el greco',
#  'josé luzán',
#  'rune jansson',
#  'claes oldenburg',
#  'tove jansson',
#  'max walter svanberg',
#  'manuel rodriguez de guzman',
#  'facundus',
#  'otto gustav carlsund',
#  'vicente juan masip',
#  'kristoffer zetterstrand',
#  'sven jonson',
#  'anna katarina boberg',
#  'hanna hirsch-pauli',
#  'hilma af klint',
#  'eugène jansson',
#  'georg pauli',
#  'juan carreno de miranda',
#  'anders zorn',
#  'marcus larson',
#  'lennart rodhe',
#  'mårten eskil winge',
#  'gosta adrian-nilsson',
#  'carl larsson',
#  'leiko ikemura',
#  'thomas hirschhorn',
#  'bruno jakob',
#  'john armleder',
#  'john bauer',
#  'olivier mosset',
#  'martin disler',
#  'h.r. giger',
#  'iseult labote',
#  'olle baertling',
#  'rudolf de crignis',
#  'samuel buri',
#  'james licini',
#  'niele toroni',
#  'ben',
#  'theo gerber',
#  'dominique appia',
#  'jean tinguely',
#  'helmut federle',
#  'daniel spoerri',
#  'markus raetz',
#  'mario comensoli',
#  'richard paul lohse',
#  'verena loewensberg',
#  'hans hinterreiter',
#  'alberto giacometti',
#  'gottfried honegger',
#  'françois barraud',
#  'fritz glarner',
#  'max gubler',
#  'serge brignoni',
#  'varlin',
#  'leo leuppi',
#  'sophie taeuber-arp',
#  'gerard schneider',
#  'camille graeser',
#  'le corbusier',
#  'carlos schwabe',
#  'max bill',
#  'helen dahm',
#  'johannes itten',
#  'alice bailly',
#  'dieter roth',
#  'meret oppenheim',
#  'adolf dietrich',
#  'felix vallotton',
#  'adolf wölfli',
#  'marianne von werefkin',
#  'giovanni segantini',
#  'robert strubin',
#  'cuno amiet',
#  'paul klee',
#  'louis soutter',
#  'eugène burnand',
#  'arnold böcklin',
#  'gustave buchet',
#  'antonio ciseri',
#  'eugène grasset',
#  'angelica kauffman',
#  'karl bodmer',
#  'jean-étienne liotard',
#  'konrad witz',
#  'henry fuseli',
#  'ayse erkmen',
#  'erol akyavaş',
#  'ozdemir atlan',
#  'fusun onur',
#  'omer uluc',
#  'burhan dogancay',
#  'louis léopold robert',
#  'adnan coker',
#  'mustafa duzgunman',
#  'mario prassinos',
#  'nuri iyem',
#  'fikret mualla saygi',
#  'princess fahrelnissa zeid',
#  'abidin dino',
#  'albert bitran',
#  'huseyin avni lifij',
#  'necmeddin okyay',
#  'charles gleyre',
#  'hoca ali riza',
#  'osman hamdi',
#  'mustafa rakim',
#  'ibrahim calli',
#  'mihri musfik',
#  'sheikh hamdullah',
#  'albrecht anker',
#  'hafiz osman',
#  'carmelo arden quin',
#  'josé pedro costigliolo',
#  'ferdinand hodler',
#  'theophile steinlen',
#  'joaquin torres garcia',
#  'al-jazari',
#  'ahmed karahisari',
#  'hatip mehmed efendi',
#  'sašo vrabič',
#  'martin benka',
#  'albin brunovsky',
#  'marko pogacnik',
#  'matej sternen',
#  'gyula kosice',
#  'steve wheeler',
#  'israel tsvaygenbaum',
#  'luis álvarez roure',
#  'andrey shishkin',
#  'pedro figari',
#  'paweł kluza',
#  'rafal bujnowski',
#  'josé campeche',
#  'zahrah al-ghamdi',
#  'm.f. husain',
#  'francisco oller',
#  'yulia mamontova',
#  'kim prisu',
#  'nemanja vučković',
#  'goran vojinovic',
#  'lech jankowski',
#  'paulo tercio',
#  'adrian ghenie',
#  'alfred freddy krupa',
#  'dumitru gorzo',
#  'mihai sârbulescu',
#  'florin ciulache',
#  'mircea cantor',
#  'nicolae maniu',
#  'otto constantin',
#  'florin maxa',
#  'sorin ilfoveanu',
#  'małgorzata serwatka',
#  ...]

# %% [markdown]
# # WikiArt Dataset

# %% [markdown]
# ## Loading in Data

# %%
paintings = load_dataset('huggan/wikiart')
paintings = paintings['train']
# Out:
# Resolving data files:   0%|          | 0/72 [00:00<?, ?it/s]
# /home/rmohe01/miniforge3/envs/MIE1517_Project/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
len(paintings)
# Out:
# 81444

# %%
paintings[35]['image']

# %%
def crop_and_export_to_zip(zip_filename, data, crop_size=(512, 512)):
    '''
    Helper function to crop and compress images for exporting into a smaller dataset
    '''
    # Create a zip file
    with zipfile.ZipFile(zip_filename, 'w') as zip_file:
        # Loop through all the images in the dataset
        for i, row in tqdm(enumerate(data)):
            # get the image
            img = row['image']
            # get the side information (everything in the row but the image)
            side_info = row.copy()
            side_info.pop('image')
            image_filename = f"cropped_image_{i}.jpg"
            json_filename = f"cropped_image_{i}.json"

            # Get the dimensions of the image
            img_width, img_height = img.size

            # Ensure the crop size is not larger than the image
            crop_width, crop_height = min(crop_size[0], img_width), min(crop_size[1], img_height)

            # Check if the image is smaller than the desired crop size
            if img_width < crop_width or img_height < crop_height:
                print(f"Image {i} is too small for the desired crop size.")
                continue

            # Calculate random position for the crop
            left = random.randint(0, img_width - crop_width)
            upper = random.randint(0, img_height - crop_height)

            # Perform the crop
            cropped_img = img.crop((left, upper, left + crop_width, upper + crop_height))

            # Convert the cropped image to RGB
            cropped_img = cropped_img.convert('RGB')

            # Save the cropped image in JPEG format with optimization and reduced quality
            img_bytes_io = io.BytesIO()
            cropped_img.save(img_bytes_io, 'JPEG', optimize=True, quality=85)
            img_bytes_io.seek(0)

            # Write the cropped image bytes to the zip file
            zip_file.writestr(image_filename, img_bytes_io.read())

            # Write the side information to a JSON file and add it to the zip file
            zip_file.writestr(json_filename, json.dumps(side_info))

# %%
export_location = 'data/cropped_paintings.zip'
crop_and_export_to_zip(export_location, paintings)
# Out:
# 81444it [15:56, 85.14it/s]
